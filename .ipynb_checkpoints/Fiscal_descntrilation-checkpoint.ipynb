# min      2.678965    0.346344
# 25%      4.719118    0.719943
# 50%      5.451865    0.874467
# 75%      6.130227    1.350684
# max      7.713901    3.736935

# %%
panel_data.Disgas.head()
# Out:
# 0    3.352385
# 1    3.391147
# 2    3.339322
# 3    3.858622
# 4    3.844708
# Name: Disgas, dtype: float64

# %%
df = panel_data

# %%
df.head()
# Out:
#    prov  year    Disgas        fd     popla      inst   volucar  GrowthGDP
# 0     1  2003  3.352385  0.897847  6.764595  0.297002  5.599014   3.291698
# 1     1  2004  3.391147  0.908318  6.789689  0.307229  5.728930   3.314435
# 2     1  2005  3.339322  0.911130  6.819385  0.290768  5.883434   3.187040
# 3     1  2006  3.858622  0.914212  6.859530  0.269954  6.029146   2.981870
# 4     1  2007  3.844708  0.919127  6.905312  0.254844  6.176491   2.955008

# %%
df.describe()
# Out:
#              prov        year      Disgas          fd       popla        inst  \
# count  330.000000   330.00000  330.000000  330.000000  330.000000  330.000000
# mean    15.500000  2008.00000    4.920663    0.792509    5.412108    0.472866
# std      8.668586     3.16708    0.829269    0.081294    1.254841    0.076314
# min      1.000000  2003.00000    1.481605    0.563511    2.003730    0.216787
# 25%      8.000000  2005.00000    4.628631    0.734124    4.983409    0.434613
# 50%     15.500000  2008.00000    5.081151    0.799664    5.633351    0.487342
# 75%     23.000000  2011.00000    5.489704    0.850870    6.226029    0.526272
# max     30.000000  2013.00000    6.117129    0.935882    8.140858    0.590454
#
#           volucar   GrowthGDP
# count  330.000000  330.000000
# mean     5.408389    1.120771
# std      1.028508    0.642967
# min      2.678965    0.346344
# 25%      4.719118    0.719943
# 50%      5.451865    0.874467
# 75%      6.130227    1.350684
# max      7.713901    3.736935

# %%
df.Disgas.head()
# Out:
# 0    3.352385
# 1    3.391147
# 2    3.339322
# 3    3.858622
# 4    3.844708
# Name: Disgas, dtype: float64

# %%
sns.distplot(df.Disgas);

# %%
sns.distplot(df.fd)

# %%
sns.lmplot(x="fd", y="Disgas", data=df,
           lowess=False);

# %%
import numpy as np
g = sns.JointGrid(x="fd", y="Disgas", data=df )
g = g.plot_joint(plt.scatter, color="m", edgecolor="white")
#g = g.plot(sns.regplot)
_ = g.ax_marg_x.hist(df["fd"], color="b", alpha=.6,
                   bins = 40 )
_ = g.ax_marg_y.hist(df["Disgas"], color="r", alpha=.6,
                      orientation="horizontal",
                   bins = 40  )

# kde plot
#sns.jointplot(x="fd", y="Disgas", data=df, kind="kde")
#g = g.plot_joint(sns.kdeplot, cmap="Blues_d")
#g = g.plot_marginals(sns.kdeplot, shade=True)

# %%
import numpy as np
g = sns.JointGrid(x="fd", y="Disgas", data=df)
g = g.plot_joint(plt.scatter, color="m", edgecolor="white")
#g = g.plot(sns.regplot)
_ = g.ax_marg_x.hist(df["fd"], color="b", alpha=.6,
                   bins = 40 )
_ = g.ax_marg_y.hist(df["Disgas"], color="r", alpha=.6,
                      orientation="horizontal",
                   bins = 40  )

# %%
df.describe()
# Out:
#              prov        year      Disgas          fd       popla        inst  \
# count  330.000000   330.00000  330.000000  330.000000  330.000000  330.000000
# mean    15.500000  2008.00000    4.920663    0.792509    5.412108    0.472866
# std      8.668586     3.16708    0.829269    0.081294    1.254841    0.076314
# min      1.000000  2003.00000    1.481605    0.563511    2.003730    0.216787
# 25%      8.000000  2005.00000    4.628631    0.734124    4.983409    0.434613
# 50%     15.500000  2008.00000    5.081151    0.799664    5.633351    0.487342
# 75%     23.000000  2011.00000    5.489704    0.850870    6.226029    0.526272
# max     30.000000  2013.00000    6.117129    0.935882    8.140858    0.590454
#
#           volucar   GrowthGDP
# count  330.000000  330.000000
# mean     5.408389    1.120771
# std      1.028508    0.642967
# min      2.678965    0.346344
# 25%      4.719118    0.719943
# 50%      5.451865    0.874467
# 75%      6.130227    1.350684
# max      7.713901    3.736935

# %%
g = (sns.jointplot(x="fd", y="Disgas", data=df, kind="hex", stat_func=None)
        .set_axis_labels("fd", "Disgas"))

# %%
sns.pairplot(df)
sns.savefig("output.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-bd2b72de34f3> in <module>()
#       1 sns.pairplot(df)
# ----> 2 sns.savefig("output.png")
#
# AttributeError: 'module' object has no attribute 'savefig'

# %%
g = sns.pairplot(df, kind="reg")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.year.head()
# Out:
# 0    2003
# 1    2004
# 2    2005
# 3    2006
# 4    2007
# Name: year, dtype: int64

# %%
df.year = df.year.astype('category')

# %%
df.year.head()
# Out:
# 0    2003
# 1    2004
# 2    2005
# 3    2006
# 4    2007
# Name: year, dtype: category
# Categories (11, int64): [2003, 2004, 2005, 2006, ..., 2010, 2011, 2012, 2013]

# %%
g = sns.pairplot(df, hue="year")

# %%
df1 = df

# %%
df1.head()
# Out:
#    prov  year    Disgas        fd     popla      inst   volucar  GrowthGDP
# 0     1  2003  3.352385  0.897847  6.764595  0.297002  5.599014   3.291698
# 1     1  2004  3.391147  0.908318  6.789689  0.307229  5.728930   3.314435
# 2     1  2005  3.339322  0.911130  6.819385  0.290768  5.883434   3.187040
# 3     1  2006  3.858622  0.914212  6.859530  0.269954  6.029146   2.981870
# 4     1  2007  3.844708  0.919127  6.905312  0.254844  6.176491   2.955008

# %%
df1.drop(df1.columns[[0, 4,5,6,7]], axis=1, inplace=True)

# %%
df1.head()
# Out:
#    year    Disgas        fd
# 0  2003  3.352385  0.897847
# 1  2004  3.391147  0.908318
# 2  2005  3.339322  0.911130
# 3  2006  3.858622  0.914212
# 4  2007  3.844708  0.919127

# %%
df1.year.head()
# Out:
# 0    2003
# 1    2004
# 2    2005
# 3    2006
# 4    2007
# Name: year, dtype: category
# Categories (11, int64): [2003, 2004, 2005, 2006, ..., 2010, 2011, 2012, 2013]

# %%
g = sns.pairplot(df1, hue="year")

# %%
df2 = df1

# %%
df2.head()
# Out:
#    year    Disgas        fd
# 0  2003  3.352385  0.897847
# 1  2004  3.391147  0.908318
# 2  2005  3.339322  0.911130
# 3  2006  3.858622  0.914212
# 4  2007  3.844708  0.919127

# %%
df2.drop(df2.columns[[0]], axis=1, inplace=True)

# %%
df2.head()
# Out:
#      Disgas        fd
# 0  3.352385  0.897847
# 1  3.391147  0.908318
# 2  3.339322  0.911130
# 3  3.858622  0.914212
# 4  3.844708  0.919127

# %%
g = sns.pairplot(df2, kind="reg")
